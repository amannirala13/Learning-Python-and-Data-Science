# %%
a= [1,2,3,4] # Change the value of set A here
b=[1,2,3,5,6,5,7,8] # Change the value of set B here
c=a
for i in range (len(b)):
    flag=0
    for j in range(len(c)):
        if b[i]==c[j]:
            flag=1
    if(flag==0):
        c.append(b[i])
print(c)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
