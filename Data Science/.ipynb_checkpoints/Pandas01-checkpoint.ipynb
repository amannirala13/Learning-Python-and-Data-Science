# %%
import pandas as pd
import matplotlib.pyplot as plt
 
df1 = pd.DataFrame({"Int_Rate":[2,1,2,3], "IND_GDP":[50,45,45,67]}, index=[2001, 2002,2003,2004])
 
df2 = pd.DataFrame({"Low_Tier_HPI":[50,45,67,34],"Unemployment":[1,3,5,6]}, index=[2001, 2003,2004,2004])
 
joined= df1.join(df2)
    
print(joined)
plt.plot(joined)
plt.show()

print(joined.head(2))
plt.plot(joined.head(2))
plt.show()

print(joined.tail(2))
plt.plot(joined.tail(2))
plt.show()

df3= pd.DataFrame({ "HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],"IND_GDP":[50,45,45,67]}, index=[2001, 2002,2003,2004])
 
df4=pd.DataFrame({ "HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],"IND_GDP":[50,45,45,67]}, index=[2005, 2006,2007,2008])
 
merged= pd.merge(df3,df4)
 
print(merged)
plt.plot(merged)
plt.show()

print(merged.head(2))
plt.plot(merged.head(2))
plt.show()

print(merged.tail(2))
plt.plot(merged.tail(2))
plt.show()
# Out:
#       Int_Rate  IND_GDP  Low_Tier_HPI  Unemployment
# 2001         2       50          50.0           1.0
# 2002         1       45           NaN           NaN
# 2003         2       45          45.0           3.0
# 2004         3       67          67.0           5.0
# 2004         3       67          34.0           6.0
#       Int_Rate  IND_GDP  Low_Tier_HPI  Unemployment
# 2001         2       50          50.0           1.0
# 2002         1       45           NaN           NaN
#       Int_Rate  IND_GDP  Low_Tier_HPI  Unemployment
# 2004         3       67          67.0           5.0
# 2004         3       67          34.0           6.0
#    HPI  Int_Rate  IND_GDP
# 0   80         2       50
# 1   90         1       45
# 2   70         2       45
# 3   60         3       67
#    HPI  Int_Rate  IND_GDP
# 0   80         2       50
# 1   90         1       45
#    HPI  Int_Rate  IND_GDP
# 2   70         2       45
# 3   60         3       67

# %%
st=input("Enter String")
st2=st[len(st)::-1]
print(st,"\n")
print(st2,"\n")
if st2==st:
    print("Yes a palindrome")
else:
    print("No a palindrome")
# Out:
# Enter String aman
# aman
#
# nama
#
# No a palindrome

# %%
st3 = input("Enter String")
c=0
for i in range (len(st3)):
    if st3[i]==' ':
        c+=1
print('No of words= ',c+1)
# Out:
# Enter String aman nirala
# No of words=  2

# %%
st3 = input("Enter String").strip()
c=0
for i in range (len(st3)):
    if st3[i]==' ':
        for j in range(i,len(st3)):
            i=j
            if st3[j] != ' ':
                c+=1
                break;
print('No of words= ',c+1)
# Out:
# Enter String aman  nirala
# No of words=  3
